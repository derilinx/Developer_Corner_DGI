# %% [markdown]
# ## Demo On Combining Multiple DGI Datasets:
#
# This gives brief idea on how datasets can be combined for analysis/visualization purposes. Three datasest are taken for demo purpose. They are -
#
#
# <li>South Dublin Libraries</li>
# <li>Limerick Libraries</li>
# <li>Wexford Libraries</li>

# %% [markdown]
# ##### Import all necessary libraries:

# %%
import requests
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import sys
import pandas as pd
from pyjstat import pyjstat
import numpy as np
from pyjstat import pyjstat
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns
import json
from geopy.geocoders import Nominatim
from googlemaps import googlemaps
import pyproj
from geopy.geocoders import GoogleV3
import time
import sys
from bs4 import BeautifulSoup
from googlesearch import search 
import urllib
import folium
import pandas

# %% [markdown]
# ## Search the datasets given query:
#
# This funtion returns the meta infoemation about matching package. Required resource can be selected from the result of below funtion.

# %%
def package_search(url, query):
    
    try:
        
        response = requests.get(url+'api/3/action/package_search', {'q':query})
        results = response.json()
        
        if results['success'] is not True:
            raise SystemError
            
        if len(results['result']) == 0:
            raise TypeError
            
        return results['result']

    except SystemError:
        
        print("API failure - ")
        sys.exit(1)
        
    except TypeError:
        
        print("No results found for a given qquery!!")
        sys.exit(1)
        
    except Exception as e:
        print(e)
        sys.exit(1)
    

res = package_search('https://data.gov.ie/', 'libraries')
print(res)
# Out:
# {'count': 29, 'sort': 'score desc, metadata_modified desc', 'facets': {}, 'results': [{'license_title': 'Creative Commons Attribution 4.0', 'maintainer': 'Not supplied', 'issued': '2013-12-18', 'private': False, 'maintainer_email': 'data@smartdublin.ie', 'num_tags': 3, 'frequency': 'Irregular', 'id': 'cd8ef111-10da-4abd-a9dc-0e82c9fd256e', 'metadata_created': '2015-09-13T15:34:06.081426', 'metadata_modified': '2018-03-05T15:54:11.594082', 'author': 'Not supplied', 'author_email': 'data@smartdublin.ie', 'temporal': '2013-01-01 to 2013-12-31', 'theme': 'Arts', 'state': 'active', 'version': '1.0', 'relationships_as_object': [], 'license_id': 'CC-BY-4.0', 'type': 'dataset', 'resources': [{'cache_last_updated': None, 'package_id': 'cd8ef111-10da-4abd-a9dc-0e82c9fd256e', 'datastore_active': False, 'id': '01ac1df7-76c9-4177-a629-51de75850ee5', 'size': None, 'state': 'active', 'api_response_formats': [], 'hash': '', 'description': 'South Dublin Libraries', 'format': 'CSV', 'mimetype_inner': None, 'url_type': None, 'date': '2018-07-18', 'mimetype': None, 'cache_url': None, 'name': 'South Dublin Libraries', 'created': '2016-07-04T15:48:01.163166', 'url': 'https://data.smartdublin.ie/dataset/cd8ef111-10da-4abd-a9dc-0e82c9fd256e/resource/01ac1df7-76c9-4177-a629-51de75850ee5/download/sdlibraries.csv', 'api_access_url': '', 'last_modified': '2016-07-04T15:48:01.104939', 'position': 0, 'revision_id': '1c79e408-9225-4749-8612-174b09b3dbbf', 'resource_type': None, 'api_type': ''}], 'updated': '2013-12-11', 'num_resources': 1, 'tags': [{'vocabulary_id': None, 'state': 'active', 'display_name': 'Arts Culture and Heritage', 'id': '38929cb4-a0d7-4dc5-98d2-7232ae762e72', 'name': 'Arts Culture and Heritage'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'arts-culture-heritage', 'id': '85d1710b-7eef-4a30-9497-b84dca4b908c', 'name': 'arts-culture-heritage'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'libraries', 'id': '81004ef1-0f40-4e05-baae-41b5eb5dc106', 'name': 'libraries'}], 'language': 'en', 'groups': [], 'creator_user_id': 'ef08264c-676d-48c5-aaad-6ce8aa18d521', 'relationships_as_subject': [], 'spatial_other': 'South Dublin', 'organization': {'description': '', 'created': '2018-03-05T11:29:36.354804', 'title': 'South Dublin County Council', 'name': 'south-dublin-county-council', 'is_organization': True, 'state': 'active', 'image_url': '', 'revision_id': '4a212282-4b1c-4913-bf88-7b8d487aff77', 'type': 'organization', 'id': 'south-dublin-county-council', 'approval_status': 'approved'}, 'name': 'libraries', 'isopen': True, 'rights': 'The data provided is for general information purposes only. It is provided by South Dublin County Council and while we endeavour to keep the information up to date and correct, we make no representations or warranties of any kind, express or implied, about the completeness, accuracy, reliability or suitability of the information or related graphics contained. Any reliance you place on such information is therefore strictly at your own risk. In no event will we be liable for any loss or damage including without limitation, indirect or consequential loss or damage, or any loss or damage whatsoever arising from loss of data or profits arising out of, or in connection with, the use of this report.', 'url': 'https://data.smartdublin.ie/dataset/libraries', 'notes': 'Location of South Dublin Libraries\r\nIncludes contact information, opening hours & facilities. For more information see http://www.southdublinlibraries.ie/', 'owner_org': 'south-dublin-county-council', 'srs': ['epsg:4326'], 'extras': [{'key': 'collection_name', 'value': 'dublinked-ckan'}, {'key': 'harvest_object_id', 'value': '654840eb-3cfe-4f9e-8d74-1860468dfaac'}, {'key': 'harvest_source_id', 'value': 'ded5188d-5c1a-441f-8438-a4b42f021c6c'}, {'key': 'harvest_source_title', 'value': 'Dublinked'}], 'license_url': 'https://creativecommons.org/licenses/by/4.0/', 'title': 'Libraries', 'revision_id': '1c79e408-9225-4749-8612-174b09b3d ...

# %% [markdown]
# ### Selected resource/data ids are:
#
# <br>
# <li>South Dublin Libraries - id:'cd8ef111-10da-4abd-a9dc-0e82c9fd256e' format: 'csv'</li>
# <li>Limerick Libraries - id:'042801f0-beb9-4d46-83bf-80a82b23a963' format: 'json'</li>
# <li>Wexford Libraries - id:'708a6a3c-337a-4109-831a-bb71e3e2a35d' format: 'csv'</li>
#
# Note: id - is the package_id and resc_arr_ind - array index of the resources that need to be extracted
#
# ### Function to extract data for csv or json:

# %%
def extract_pkg_data(url, pkg_id, resc_arr_ind):
    
    try:
        
        param = {'id': pkg_id}
        response = requests.get(url+'api/3/action/package_show', param)
        results = response.json()
        
        if not results['success']:
            raise SystemError

        if len(results['result']) == 0:
            return ("No package found")
        
        if results['result']['resources'][resc_arr_ind]['format'].lower() == 'csv':
        
            dataset = pd.read_csv(results['result']['resources'][resc_arr_ind]['url'], encoding = 'ISO-8859-1')
            #df = dataset.write('dataframe')

            return dataset
        
        elif ((results['result']['resources'][resc_arr_ind]['format'].lower() == 'geojson') or 
        (results['result']['resources'][resc_arr_ind]['format'].lower() == 'json')):
            
            response_json = requests.get(results['result']['url'])
            data_json = json.dumps(response_json.json())
            
                
            return json.loads(data_json)
        
        else:
            
            return results['result']
        
    
    except SystemError:
        
        print("Request Failure, please check the URL or the parameters")
        sys.exit(1)
        
    except Exception as e:
        
        print(e)
        sys.exit(1)

# %% [markdown]
# ### Libraries in South Dublin County:

# %%
sd_cnty = extract_pkg_data('https://data.gov.ie/', 'cd8ef111-10da-4abd-a9dc-0e82c9fd256e', 0)
sd_cnty.head()
# Out:
#   Council_ID     Administrative_Authority                 Name  \
# 0        SD1  South Dublin County Council       County Library
# 1        SD2  South Dublin County Council    Ballyroan Library
# 2        SD3  South Dublin County Council  Castletymon Library
# 3        SD4  South Dublin County Council   Clondalkin Library
# 4        SD5  South Dublin County Council        Lucan Library
#
#                      Address1              Address2         Town  Postcode  \
# 0              Library Square  Belgard Square North     Tallaght      24.0
# 1         Orchardstown Avenue                   NaN  Rathfarnham      14.0
# 2            Tymon Road North                   NaN     Tallaght      24.0
# 3              Monastery Road                   NaN   Clondalkin      22.0
# 4  Superquinn Shopping Centre        Newcastle Road        Lucan       NaN
#
#    County            Phone                       Email  \
# 0  Dublin  +353 1 462 0073        talib@sdublincoco.ie
# 1  Dublin  +353 1 494 1900    ballyroan@sdublincoco.ie
# 2  Dublin  +353 1 452 4888  castletymon@sdublincoco.ie
# 3  Dublin  +353 1 459 3315  clondalkin@sdublincoco.ie
# 4  Dublin  +353 1 621 6422        lucan@sdublincoco.ie
#
#                                              Website  \
# 0  http://www.southdublinlibraries.ie/find-librar...
# 1  http://www.southdublinlibraries.ie/find-librar...
# 2  http://www.southdublinlibraries.ie/find-librar...
# 3  http://www.southdublinlibraries.ie/find-librar...
# 4  http://www.southdublinlibraries.ie/find-librar...
#
#                                                Image Opening_Hours_Monday  \
# 0  http://www.southdublinlibraries.ie/sites/all/l...          09:45-20:00
# 1  http://www.southdublinlibraries.ie/sites/all/l...          09:45-20:00
# 2  http://www.southdublinlibraries.ie/sites/all/l...          09:45-17:00
# 3  http://www.southdublinlibraries.ie/sites/all/l...          09:45-20:00
# 4  http://www.southdublinlibraries.ie/sites/all/l...          09:45-20:00
#
#   Opening_Hours_Tuesday Opening_Hours_Wednesday Opening_Hours_Thursday  \
# 0           09:45-20:00             09:45-20:00            09:45-20:00
# 1           09:45-20:00             09:45-20:00            09:45-20:00
# 2           09:45-17:00             09:45-17:00            09:45-17:00
# 3           09:45-20:00             09:45-20:00            09:45-20:00
# 4           09:45-20:00             09:45-20:00            09:45-20:00
#
#   Opening_Hours_Friday Opening_Hours_Saturday  WGS84_Latitude  WGS84_Longitude
# 0          09:45-16:30            09:45-16:30       53.288466        -6.373348
# 1          09:45-16:30            09:45-16:30       53.290678        -6.299322
# 2          09:45-16:30            09:45-16:30       53.295663        -6.342031
# 3          09:45-16:30            09:45-16:30       53.320720        -6.388526
# 4          09:45-16:30            09:45-16:30       53.347955        -6.453018

# %% [markdown]
# #### Data processing:

# %%
def southDublin_data_process(dt):
    
    sd_cnty = dt
    sd_cnty.drop(['Council_ID', 'Image', 'Postcode'], axis=1, inplace=True)
    sd_cnty.rename(columns={'WGS84_Latitude': 'Latitude', 'WGS84_Longitude': 'Longitude'}, inplace=True)

    
    try:
        
        for index, cont in sd_cnty.iterrows():

            if (cont['Address2'] is np.nan) and (cont['Town'] is not np.nan):

                sd_cnty.loc[index, 'Addr'] = cont['Town']

            elif (cont['Address2'] is not np.nan) and (cont['Town'] is np.nan):

                sd_cnty.loc[index, 'Addr'] = cont['Address2']

            elif (cont['Address2'] is np.nan) and (cont['Town'] is np.nan):

                sd_cnty.loc[index, 'Addr'] = None

            else:

                sd_cnty.loc[index, 'Addr'] = str(cont['Address2']) +", "+ str(cont['Town'])

        sd_cnty.drop(['Address2', 'Town'], axis=1, inplace=True)
        sd_cnty.rename(columns={'Addr': 'Address2'}, inplace=True)
        sd_cnty.replace(np.nan, None, inplace=True)
        
    except Exception as e:
        
        print(e)
        sys.exit(1)

    return sd_cnty

sd_cnty = southDublin_data_process(sd_cnty)
sd_cnty.head()
# Out:
#       Administrative_Authority                 Name  \
# 0  South Dublin County Council       County Library
# 1  South Dublin County Council    Ballyroan Library
# 2  South Dublin County Council  Castletymon Library
# 3  South Dublin County Council   Clondalkin Library
# 4  South Dublin County Council        Lucan Library
#
#                      Address1  County            Phone  \
# 0              Library Square  Dublin  +353 1 462 0073
# 1         Orchardstown Avenue  Dublin  +353 1 494 1900
# 2            Tymon Road North  Dublin  +353 1 452 4888
# 3              Monastery Road  Dublin  +353 1 459 3315
# 4  Superquinn Shopping Centre  Dublin  +353 1 621 6422
#
#                         Email  \
# 0        talib@sdublincoco.ie
# 1    ballyroan@sdublincoco.ie
# 2  castletymon@sdublincoco.ie
# 3  clondalkin@sdublincoco.ie
# 4        lucan@sdublincoco.ie
#
#                                              Website Opening_Hours_Monday  \
# 0  http://www.southdublinlibraries.ie/find-librar...          09:45-20:00
# 1  http://www.southdublinlibraries.ie/find-librar...          09:45-20:00
# 2  http://www.southdublinlibraries.ie/find-librar...          09:45-17:00
# 3  http://www.southdublinlibraries.ie/find-librar...          09:45-20:00
# 4  http://www.southdublinlibraries.ie/find-librar...          09:45-20:00
#
#   Opening_Hours_Tuesday Opening_Hours_Wednesday Opening_Hours_Thursday  \
# 0           09:45-20:00             09:45-20:00            09:45-20:00
# 1           09:45-20:00             09:45-20:00            09:45-20:00
# 2           09:45-17:00             09:45-17:00            09:45-17:00
# 3           09:45-20:00             09:45-20:00            09:45-20:00
# 4           09:45-20:00             09:45-20:00            09:45-20:00
#
#   Opening_Hours_Friday Opening_Hours_Saturday   Latitude  Longitude  \
# 0          09:45-16:30            09:45-16:30  53.288466  -6.373348
# 1          09:45-16:30            09:45-16:30  53.290678  -6.299322
# 2          09:45-16:30            09:45-16:30  53.295663  -6.342031
# 3          09:45-16:30            09:45-16:30  53.320720  -6.388526
# 4          09:45-16:30            09:45-16:30  53.347955  -6.453018
#
#                          Address2
# 0  Belgard Square North, Tallaght
# 1                     Rathfarnham
# 2                        Tallaght
# 3                      Clondalkin
# 4           Newcastle Road, Lucan

# %% [markdown]
# ### Libraries in Limerick City and County:
#
# Data process/ enrichment for limerick libraries is done in DGI Data Enrichment notebook. Data obtaibned from DGI Data Enrichment notebook is utilised here.

# %%
lmk_data = pd.read_csv('lmk_lib_cnt.csv')
lmk_data.head()
# Out:
#                Address1                                           Address2  \
# 0             Bridge St   Abbeyfeale West,  Abbeyfeale,  Co. Limerick, ...
# 1               Main St        Blackabbey,  Adare,  Co. Limerick,  Ireland
# 2              The Quay                  Askeaton,  Co. Limerick,  Ireland
# 3  Caherconlish Library   Hundredacres East,  Caherconlish,  Co. Limeri...
# 4          Gortnascarry                 Cappamore,  Co. Limerick,  Ireland
#
#             Administrative Autority    County   Latitude  Longitude  \
# 0  Limerick City and County Council  Limerick  52.383975  -9.301578
# 1  Limerick City and County Council  Limerick  52.564622  -8.790106
# 2  Limerick City and County Council  Limerick  52.600884  -8.973165
# 3  Limerick City and County Council  Limerick  52.595662  -8.472314
# 4  Limerick City and County Council  Limerick  52.615463  -8.335975
#
#                    Name  monday                           tuesday  \
# 0    Abbeyfeale Library  closed           10am - 1pm    2pm - 5pm
# 1         Adare Library  closed  10am -1pm, 2pm – 5pm   6pm – 8pm
# 2      Askeaton Library  closed                               NaN
# 3  Caherconlish Library     NaN                               NaN
# 4     Cappamore Library  Closed            10am - 1pm   2pm - 5pm
#
#                  wednesday                          thursday  \
# 0    1pm - 5pm   6pm - 8pm             1pm - 5pm   6pm - 8pm
# 1  10am -1pm and 2pm – 5pm  10am-1pm, 2pm – 5pm    6pm – 8pm
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4   10am - 1pm   5pm - 8pm            10am - 1pm   2pm - 5pm
#
#                     friday                saturday  sunday  \
# 0   10am - 1pm   2pm - 5pm  10am - 1pm   2pm - 5pm     NaN
# 1  10am -1pm and 2pm – 5pm  10am – 1pm   2pm – 5pm     NaN
# 2                      NaN                     NaN     NaN
# 3                      NaN                     NaN     NaN
# 4   10am - 1pm   2pm - 5pm                     NaN     NaN
#
#                            Email             Phone  \
# 0  abbeyfealelibrary@limerick.ie     +353 68 32488
# 1       adarelibrary@limerick.ie    +353 61 396822
# 2      askeatonlibrary@gmail.com    +353 61 392256
# 3                            NaN               NaN
# 4   cappamorelibrary@limerick.ie  + 353 61 381586
#
#                                      Closed  \
# 0  on the saturday of bank holiday weekends
# 1  on the saturday of bank holiday weekends
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                                              Website
# 0  https://www.limerick.ie/discover/eat-see-do/fa...
# 1  https://www.limerick.ie/discover/eat-see-do/fa...
# 2  https://www.limerick.ie/discover/eat-see-do/fa...
# 3  https://www.limerick.ie/discover/eat-see-do/fa...
# 4  https://www.limerick.ie/discover/eat-see-do/fa...

# %% [markdown]
# ### Libraries in Wexford:

# %%
wexford_cnty = extract_pkg_data('https://data.gov.ie/', '517abd28-7460-4512-a8e6-8e66326ed268', 1)
wexford_cnty.head()
# Out:
#           X          Y  OBJECTID  Administrative_Authority_ID  \
# 0 -6.656521  52.655778         1                           23
# 1 -6.570485  52.500419         2                           23
# 2 -6.296913  52.673352         3                           23
# 3 -6.942020  52.394292         4                           23
# 4 -6.463707  52.339089         5                           23
#
#   Administrative_Authority                        Name            Address1  \
# 0   Wexford County Council     Bunclody Library Centre            Millwood
# 1   Wexford County Council  Enniscorthy Public Library      Lymington Road
# 2   Wexford County Council               Gorey Library  Gorey Civic Centre
# 3   Wexford County Council     New Ross Public Library        Barrack Lane
# 4   Wexford County Council        Wexford Town Library       Mallin Street
#
#      Address2         Town  Postcode    ...     Image  \
# 0         NaN     Bunclody  Y21 E970    ...       NaN
# 1         NaN  Enniscorthy  Y21 AD92    ...       NaN
# 2  The Avenue        Gorey  Y25 WK37    ...       NaN
# 3         NaN     New Ross  Y34 NW56    ...       NaN
# 4         NaN      Wexford  Y35 AY20    ...       NaN
#
#                                 Opening_Hours_Monday  \
# 0  10.30 - 5.30, Closed for lunch between 1pm and...
# 1    10.30 am - 5.30 pm Closed for lunch 1.00 - 2.00
# 2      10.30 - 5.30 Closed for lunch between 1 and 2
# 3  10.30am - 5.30pm Closed for lunch 1.00pm - 2.00pm
# 4                                       10.30 - 5.30
#
#                Opening_Hours_Tuesday            Opening_Hours_Wednesday  \
# 0       10.30 - 5.30, Open lunchtime       10.30 - 5.30, Open lunchtime
# 1  10.30 am - 5.30 pm Open lunchtime  10.30 am - 5.30 pm Open lunchtime
# 2        10.30 - 9.00 Open lunchtime        10.30 - 5.30 Open lunchtime
# 3  10.30am - 8.30pm (Open lunchtime)  10.30am - 5.30pm (Open lunchtime)
# 4                       10.30 - 9.00                       10.30 - 5.30
#
#               Opening_Hours_Thursday  \
# 0       10.30 - 9.00, Open lunchtime
# 1  10.30 am - 8.30 pm Open lunchtime
# 2        10.30 - 9.00 Open lunchtime
# 3   10.30am - 5.30pm (Open lunchtime
# 4                       10.30 - 9.00
#
#                                 Opening_Hours_Friday  \
# 0  10.30 - 5.30, Closed for lunch between 1pm and...
# 1                  10.30 am - 5.30 pm Open lunchtime
# 2                        10.30 - 5.30 Open lunchtime
# 3                  10.30am - 5.30pm (Open lunchtime)
# 4                                       10.30 - 5.30
#
#                               Opening_Hours_Saturday WGS84Latitude  \
# 0  10.30 - 5.30, Closed for lunch  between 1pm an...     -6.656520
# 1  10.30 am - 5.30 pm Closed for lunch 1.00 - 2.0...     -6.570484
# 2   10.30 - 5.30 Closed for lunch between 1 and 2...     -6.296912
# 3  Saturday  10.30am - 5.30pm Closed for lunch 1....     -6.942020
# 4  10.30 - 5.30 Closed Saturdays of Bank Holiday ...     -6.463707
#
#   WGS84Longitude OBJECTID_1
# 0      52.655778          1
# 1      52.500419          2
# 2      52.673351          3
# 3      52.394291          4
# 4      52.339088          5
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Data process

# %%
def wexford_data_process(dt):
    
    wexford_cnty = dt
    wexford_cnty.rename(columns = {'WGS84Latitude': 'Longitude', 'WGS84Longitude': 'Latitude'}, inplace = True)
    wexford_cnty = wexford_cnty.loc[:, 'Administrative_Authority':]
    wexford_cnty.drop(['Image', 'OBJECTID_1', 'Postcode'], axis=1, inplace=True)
    wexford_cnty['Addr'] = ''
    
    try:
        
        for index, cont in wexford_cnty.iterrows():

            if (cont['Address2'] is np.nan) and (cont['Town'] is not np.nan):

                wexford_cnty.loc[index, 'Addr'] = cont['Town']

            elif (cont['Address2'] is not np.nan) and (cont['Town'] is np.nan):

                wexford_cnty.loc[index, 'Addr'] = cont['Address2']

            elif (cont['Address2'] is np.nan) and (cont['Town'] is np.nan):

                wexford_cnty.loc[index, 'Addr'] = None

            else:

                wexford_cnty.loc[index, 'Addr'] = str(cont['Address2']) +", "+ str(cont['Town'])

        wexford_cnty.drop(['Address2', 'Town'], axis=1, inplace=True)
        wexford_cnty.rename(columns={'Addr': 'Address2'}, inplace=True)
        wexford_cnty.replace(np.nan, None, inplace=True)
        
    except Exception as e:
        
        print(e)
        sys.exit(1)

    return wexford_cnty

wexford_cnty = wexford_data_process(wexford_cnty)
wexford_cnty.head()
# Out:
#   Administrative_Authority                        Name            Address1  \
# 0   Wexford County Council     Bunclody Library Centre            Millwood
# 1   Wexford County Council  Enniscorthy Public Library      Lymington Road
# 2   Wexford County Council               Gorey Library  Gorey Civic Centre
# 3   Wexford County Council     New Ross Public Library        Barrack Lane
# 4   Wexford County Council        Wexford Town Library       Mallin Street
#
#            County        Phone                          Email  \
# 0  County Wexford  053 9375466     bunclodylib@wexfordcoco.ie
# 1  County Wexford  053 9236055  enniscorthylib@wexfordcoco.ie
# 2  County Wexford  053 9421481        goreylib@wexfordcoco.ie
# 3  County Wexford   051 421877      newrosslib@wexfordcoco.ie
# 4  County Wexford  053 9196760      wexfordlib@wexfordcoco.ie
#
#                                              Website  \
# 0  http://www.wexford.ie/wex/Departments/Library/...
# 1  http://www.wexford.ie/wex/Departments/Library/...
# 2  http://www.wexford.ie/wex/Departments/Library/...
# 3  http://www.wexford.ie/wex/Departments/Library/...
# 4  http://www.wexford.ie/wex/Departments/Library/...
#
#                                 Opening_Hours_Monday  \
# 0  10.30 - 5.30, Closed for lunch between 1pm and...
# 1    10.30 am - 5.30 pm Closed for lunch 1.00 - 2.00
# 2      10.30 - 5.30 Closed for lunch between 1 and 2
# 3  10.30am - 5.30pm Closed for lunch 1.00pm - 2.00pm
# 4                                       10.30 - 5.30
#
#                Opening_Hours_Tuesday            Opening_Hours_Wednesday  \
# 0       10.30 - 5.30, Open lunchtime       10.30 - 5.30, Open lunchtime
# 1  10.30 am - 5.30 pm Open lunchtime  10.30 am - 5.30 pm Open lunchtime
# 2        10.30 - 9.00 Open lunchtime        10.30 - 5.30 Open lunchtime
# 3  10.30am - 8.30pm (Open lunchtime)  10.30am - 5.30pm (Open lunchtime)
# 4                       10.30 - 9.00                       10.30 - 5.30
#
#               Opening_Hours_Thursday  \
# 0       10.30 - 9.00, Open lunchtime
# 1  10.30 am - 8.30 pm Open lunchtime
# 2        10.30 - 9.00 Open lunchtime
# 3   10.30am - 5.30pm (Open lunchtime
# 4                       10.30 - 9.00
#
#                                 Opening_Hours_Friday  \
# 0  10.30 - 5.30, Closed for lunch between 1pm and...
# 1                  10.30 am - 5.30 pm Open lunchtime
# 2                        10.30 - 5.30 Open lunchtime
# 3                  10.30am - 5.30pm (Open lunchtime)
# 4                                       10.30 - 5.30
#
#                               Opening_Hours_Saturday  Longitude   Latitude  \
# 0  10.30 - 5.30, Closed for lunch  between 1pm an...  -6.656520  52.655778
# 1  10.30 am - 5.30 pm Closed for lunch 1.00 - 2.0...  -6.570484  52.500419
# 2   10.30 - 5.30 Closed for lunch between 1 and 2...  -6.296912  52.673351
# 3  Saturday  10.30am - 5.30pm Closed for lunch 1....  -6.942020  52.394291
# 4  10.30 - 5.30 Closed Saturdays of Bank Holiday ...  -6.463707  52.339088
#
#             Address2
# 0           Bunclody
# 1        Enniscorthy
# 2  The Avenue, Gorey
# 3           New Ross
# 4            Wexford

# %% [markdown]
# ## Final Data processing of all extracted datasets for consistent:

# %%
def process_all_libraries(sd_cnty, lmk_data, wexford_cnty):
    
    sd = sd_cnty.copy()
    lmk = lmk_data.copy()
    wex = wexford_cnty.copy()
    
    try:
    
        lmk.drop(['Closed', 'sunday'], axis=1, inplace=True)
        lmk.rename(columns={'monday': 'Opening_Hours_Monday', 'tuesday' :'Opening_Hours_Tuesday',
           'wednesday' :'Opening_Hours_Wednesday', 'thursday': 'Opening_Hours_Thursday',
        'friday' :'Opening_Hours_Friday', 'saturday':'Opening_Hours_Saturday', 
                            'Administrative Autority': 'Administrative_Authority'}, inplace=True)

        df = lmk.append([sd, wex], sort=True)
        
        df.replace(np.nan, "NA", inplace=True)
        df.fillna("NA", inplace=True)
        
        
        df['Opening_Hours_Saturday'] = df['Opening_Hours_Saturday'].apply(lambda x: x.strip().replace('\r', ' ').replace('\n', ''))
        df['County'] = df['County'].apply(lambda x: x.replace('County ', ''))
        
        return df
    
    except Exception as e:
        
        print(e)
        sys.exit(1)
    
all_lib_data = process_all_libraries(sd_cnty, lmk_data, wexford_cnty)
all_lib_data.head()
# Out:
#                Address1                                           Address2  \
# 0             Bridge St   Abbeyfeale West,  Abbeyfeale,  Co. Limerick, ...
# 1               Main St        Blackabbey,  Adare,  Co. Limerick,  Ireland
# 2              The Quay                  Askeaton,  Co. Limerick,  Ireland
# 3  Caherconlish Library   Hundredacres East,  Caherconlish,  Co. Limeri...
# 4          Gortnascarry                 Cappamore,  Co. Limerick,  Ireland
#
#            Administrative_Authority    County                          Email  \
# 0  Limerick City and County Council  Limerick  abbeyfealelibrary@limerick.ie
# 1  Limerick City and County Council  Limerick       adarelibrary@limerick.ie
# 2  Limerick City and County Council  Limerick      askeatonlibrary@gmail.com
# 3  Limerick City and County Council  Limerick                             NA
# 4  Limerick City and County Council  Limerick   cappamorelibrary@limerick.ie
#
#     Latitude  Longitude                  Name     Opening_Hours_Friday  \
# 0  52.383975  -9.301578    Abbeyfeale Library   10am - 1pm   2pm - 5pm
# 1  52.564622  -8.790106         Adare Library  10am -1pm and 2pm – 5pm
# 2  52.600884  -8.973165      Askeaton Library                       NA
# 3  52.595662  -8.472314  Caherconlish Library                       NA
# 4  52.615463  -8.335975     Cappamore Library   10am - 1pm   2pm - 5pm
#
#   Opening_Hours_Monday  Opening_Hours_Saturday  \
# 0               closed  10am - 1pm   2pm - 5pm
# 1               closed  10am – 1pm   2pm – 5pm
# 2               closed                      NA
# 3                   NA                      NA
# 4               Closed                      NA
#
#              Opening_Hours_Thursday             Opening_Hours_Tuesday  \
# 0             1pm - 5pm   6pm - 8pm           10am - 1pm    2pm - 5pm
# 1  10am-1pm, 2pm – 5pm    6pm – 8pm  10am -1pm, 2pm – 5pm   6pm – 8pm
# 2                                NA                                NA
# 3                                NA                                NA
# 4            10am - 1pm   2pm - 5pm            10am - 1pm   2pm - 5pm
#
#    Opening_Hours_Wednesday             Phone  \
# 0    1pm - 5pm   6pm - 8pm     +353 68 32488
# 1  10am -1pm and 2pm – 5pm    +353 61 396822
# 2                       NA    +353 61 392256
# 3                       NA                NA
# 4   10am - 1pm   5pm - 8pm  + 353 61 381586
#
#                                              Website
# 0  https://www.limerick.ie/discover/eat-see-do/fa...
# 1  https://www.limerick.ie/discover/eat-see-do/fa...
# 2  https://www.limerick.ie/discover/eat-see-do/fa...
# 3  https://www.limerick.ie/discover/eat-see-do/fa...
# 4  https://www.limerick.ie/discover/eat-see-do/fa...

# %% [markdown]
# ## Visualisation of Libraries location in South Dublin, Limerick and Wexford:

# %%
def location__lib_viz(all_lib_data):

    df= all_lib_data

    map=folium.Map(location=[df['Latitude'].mean(),df['Longitude'].mean()],zoom_start=7,tiles='openstreetmap')


    fg=folium.FeatureGroup(name="Library Locations")

    for lat,lon,name, address1, address2, county, friday, monday, saturday, thursday, tuesday, wednesday, phone, website in zip(df['Latitude'],df['Longitude'],df['Name'], df['Address1'], df['Address2'], df['County'], 
                           df['Opening_Hours_Friday'], df['Opening_Hours_Monday'], df['Opening_Hours_Saturday'], 
                            df['Opening_Hours_Thursday'], df['Opening_Hours_Tuesday'], df['Opening_Hours_Wednesday'],
                           df['Phone'], df['Website']):

        fg.add_child(folium.Marker(location=[lat,lon],
                                   popup=(folium.Popup('<style>table, th, td {border: 1px solid black; border-collapse: collapse;} th, td {padding: 5px; text-align: left;}</style><div><p><b>Name:</b><i> ' +str(name)+ '</i><br><b>County:</b><i> ' + str(county) + '</i><br><b>Address:</b><i> ' + str(address1) + ', ' + str(address2) + '</i><br><b>Phone:</b><i> ' + str(phone) + '</i><br><b>Website: </b> <a href=' + str(website) +'>'+str(website)+'</a><br><br><b>Opening Hours:</b> <br><table style="width:80%"><tr><th>Day</th><th>Hours</th></tr><tr><td>Monday</td><td>' + str(monday) + '</td></tr><tr><td>Tuesday</td><td>' + str(tuesday) + '</td></tr><tr><td>Wednesday</td><td>' + str(wednesday) + '</td></tr><tr><td>Thursday</td><td>' + str(thursday) + '</td></tr><tr><td>Friday</td><td>' + str(friday) + '</td></tr><tr><td>Saturday</td><td>' + str(saturday)+ '</td></tr><tr><td>Sunday</td><td>Closed</td></tr></table></p><p>NA: Not Available</div>')), 
                                   icon=folium.Icon(color='blue',icon_color='orange')))

    map.add_child(fg)
    map.add_child(folium.LayerControl())
    
    return map

location__lib_viz(all_lib_data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
