# %% [markdown]
# ## DGI Data Enrichment Demo:
#
# This jupyter notebook gives a brief demo on how DGI APi can also be used to extract the data and erich/improve the quality of data. In this case, how webscraping from google can be utilised to gather more information about the already existing data.
#
# ##### Import all necessary libraries:

# %%
import requests
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import sys
import pandas as pd
from pyjstat import pyjstat
import numpy as np
from pyjstat import pyjstat
import plotly.plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import seaborn as sns
import json
from geopy.geocoders import Nominatim
from googlemaps import googlemaps
import pyproj
from geopy.geocoders import GoogleV3
import time
import sys
from bs4 import BeautifulSoup
from googlesearch import search 
import urllib
import folium
import pandas

# %% [markdown]
# ### Search the datasets given query using DGI API:
#
# This funtion returns the meta infoemation about matching package. Required resource can be selected from the result of below funtion.
#
# <b>Search Query: "libraries"</b>

# %%
def package_search(url, query):
    
    try:
        
        response = requests.get(url+'api/3/action/package_search', {'q':query})
        results = response.json()
        
        if results['success'] is not True:
            raise SystemError
            
        if len(results['result']) == 0:
            raise TypeError
            
        return results['result']

    except SystemError:
        
        print("API failure - ")
        sys.exit(1)
        
    except TypeError:
        
        print("No results found for a given qquery!!")
        sys.exit(1)
        
    except Exception as e:
        print(e)
        sys.exit(1)
    

res = package_search('https://data.gov.ie/', 'libraries')
print(res)
# Out:
# {'count': 29, 'sort': 'score desc, metadata_modified desc', 'facets': {}, 'results': [{'license_title': 'Creative Commons Attribution 4.0', 'maintainer': 'Not supplied', 'issued': '2013-12-18', 'private': False, 'maintainer_email': 'data@smartdublin.ie', 'num_tags': 3, 'frequency': 'Irregular', 'id': 'cd8ef111-10da-4abd-a9dc-0e82c9fd256e', 'metadata_created': '2015-09-13T15:34:06.081426', 'metadata_modified': '2018-03-05T15:54:11.594082', 'author': 'Not supplied', 'author_email': 'data@smartdublin.ie', 'temporal': '2013-01-01 to 2013-12-31', 'theme': 'Arts', 'state': 'active', 'version': '1.0', 'relationships_as_object': [], 'license_id': 'CC-BY-4.0', 'type': 'dataset', 'resources': [{'cache_last_updated': None, 'package_id': 'cd8ef111-10da-4abd-a9dc-0e82c9fd256e', 'datastore_active': False, 'id': '01ac1df7-76c9-4177-a629-51de75850ee5', 'size': None, 'state': 'active', 'api_response_formats': [], 'hash': '', 'description': 'South Dublin Libraries', 'format': 'CSV', 'mimetype_inner': None, 'url_type': None, 'date': '2018-07-18', 'mimetype': None, 'cache_url': None, 'name': 'South Dublin Libraries', 'created': '2016-07-04T15:48:01.163166', 'url': 'https://data.smartdublin.ie/dataset/cd8ef111-10da-4abd-a9dc-0e82c9fd256e/resource/01ac1df7-76c9-4177-a629-51de75850ee5/download/sdlibraries.csv', 'api_access_url': '', 'last_modified': '2016-07-04T15:48:01.104939', 'position': 0, 'revision_id': '1c79e408-9225-4749-8612-174b09b3dbbf', 'resource_type': None, 'api_type': ''}], 'updated': '2013-12-11', 'num_resources': 1, 'tags': [{'vocabulary_id': None, 'state': 'active', 'display_name': 'Arts Culture and Heritage', 'id': '38929cb4-a0d7-4dc5-98d2-7232ae762e72', 'name': 'Arts Culture and Heritage'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'arts-culture-heritage', 'id': '85d1710b-7eef-4a30-9497-b84dca4b908c', 'name': 'arts-culture-heritage'}, {'vocabulary_id': None, 'state': 'active', 'display_name': 'libraries', 'id': '81004ef1-0f40-4e05-baae-41b5eb5dc106', 'name': 'libraries'}], 'language': 'en', 'groups': [], 'creator_user_id': 'ef08264c-676d-48c5-aaad-6ce8aa18d521', 'relationships_as_subject': [], 'spatial_other': 'South Dublin', 'organization': {'description': '', 'created': '2018-03-05T11:29:36.354804', 'title': 'South Dublin County Council', 'name': 'south-dublin-county-council', 'is_organization': True, 'state': 'active', 'image_url': '', 'revision_id': '4a212282-4b1c-4913-bf88-7b8d487aff77', 'type': 'organization', 'id': 'south-dublin-county-council', 'approval_status': 'approved'}, 'name': 'libraries', 'isopen': True, 'rights': 'The data provided is for general information purposes only. It is provided by South Dublin County Council and while we endeavour to keep the information up to date and correct, we make no representations or warranties of any kind, express or implied, about the completeness, accuracy, reliability or suitability of the information or related graphics contained. Any reliance you place on such information is therefore strictly at your own risk. In no event will we be liable for any loss or damage including without limitation, indirect or consequential loss or damage, or any loss or damage whatsoever arising from loss of data or profits arising out of, or in connection with, the use of this report.', 'url': 'https://data.smartdublin.ie/dataset/libraries', 'notes': 'Location of South Dublin Libraries\r\nIncludes contact information, opening hours & facilities. For more information see http://www.southdublinlibraries.ie/', 'owner_org': 'south-dublin-county-council', 'srs': ['epsg:4326'], 'extras': [{'key': 'collection_name', 'value': 'dublinked-ckan'}, {'key': 'harvest_object_id', 'value': '654840eb-3cfe-4f9e-8d74-1860468dfaac'}, {'key': 'harvest_source_id', 'value': 'ded5188d-5c1a-441f-8438-a4b42f021c6c'}, {'key': 'harvest_source_title', 'value': 'Dublinked'}], 'license_url': 'https://creativecommons.org/licenses/by/4.0/', 'title': 'Libraries', 'revision_id': '1c79e408-9225-4749-8612-174b09b3d ...

# %% [markdown]
# ### Selected resource/data is Limerick libraries:
#
# id: '042801f0-beb9-4d46-83bf-80a82b23a963'
#
# format: 'json'
#
# Note: id - is the package_id and resc_arr_ind - array index of the resources that need to be extracted.
#
# ### Function to extract data from DGI API:

# %%
def extract_pkg_data(url, pkg_id, resc_arr_ind):
    
    try:
        
        param = {'id': pkg_id}
        response = requests.get(url+'api/3/action/package_show', param)
        results = response.json()
        
        if not results['success']:
            raise SystemError

        if len(results['result']) == 0:
            return ("No package found")
        
        if results['result']['resources'][resc_arr_ind]['format'].lower() == 'csv':
        
            dataset = pd.read_csv(results['result']['resources'][resc_arr_ind]['url'], encoding = 'ISO-8859-1')
            #df = dataset.write('dataframe')

            return dataset
        
        elif ((results['result']['resources'][resc_arr_ind]['format'].lower() == 'geojson') or 
        (results['result']['resources'][resc_arr_ind]['format'].lower() == 'json')):
            
            response_json = requests.get(results['result']['url'])
            data_json = json.dumps(response_json.json())
            
                
            return json.loads(data_json)
        
        else:
            
            return results['result']
        
    
    except SystemError:
        
        print("Request Failure, please check the URL or the parameters")
        sys.exit(1)
        
    except Exception as e:
        
        print(e)
        sys.exit(1)

# %%
lm_lib_data = extract_pkg_data('https://data.gov.ie/', '762c93aa-f821-4ab7-8950-fe86bdf7fd2e', 0)
lm_lib_data
# Out:
# {'name': 'libraries',
#  'type': 'FeatureCollection',
#  'crs': {'type': 'name', 'properties': {'name': 'EPSG:2157'}},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [511376.631959441, 626468.356670141]},
#    'properties': {'name': 'Abbeyfeale Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [546451.335412499, 646235.075368134]},
#    'properties': {'name': 'Adare Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [534073.892464841, 650401.229900348]},
#    'properties': {'name': 'Askeaton Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [568000.663871202, 649481.618443499]},
#    'properties': {'name': 'Caherconlish Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [577240.81915693, 651685.76339251]},
#    'properties': {'name': 'Cappamore Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [556353.570780013, 654602.933814135]},
#    'properties': {'name': 'Dooradoyle Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [537983.243277909, 621223.666919806]},
#    'properties': {'name': 'Dromcollogher Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [525228.40262111, 651539.245744664]},
#    'properties': {'name': 'Foynes Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [579961.087822859, 627695.469310381]},
#    'properties': {'name': 'Galbally Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [512905.494124339, 647366.150490898]},
#    'properties': {'name': 'Glin Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [570667.345412987, 635582.047679064]},
#    'properties': {'name': 'Hospital Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [567965.177778677, 623114.75243686]},
#    'properties': {'name': 'Kilfinane Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [560660.337075169, 628147.252832191]},
#    'properties': {'name': 'Kilmallock Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [528221.495251721, 634152.582120669]},
#    'properties': {'name': 'Newcastle West Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [536021.699524955, 641382.585812517]},
#    'properties': {'name': 'Rathkeale'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [555539.714959619, 653745.226300916]},
#    'properties': {'name': 'Lissanalta House'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [556858.346991911, 658797.866525052]},
#    'properties': {'name': 'Watch House Cross Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [557846.89113737, 657359.971402674]},
#    'properties': {'name': 'Limerick City Library'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [558260.277912349, 655598.562401562]},
#    'properties': {'name': 'Roxboro Library'}}]}

# %% [markdown]
# ### Data Enrichment for Limerick libraries:
#
# This data enrichment is split into 2 stages:
#
# <li>Google Geolocation API: Used to retieve address and cordinates.</li>
# <li>Webscrapping: Used to retieve email, phone and opening hours.</li>
#
# ##### Case 1: Google geolocation to get address and cordinates -

# %%
def limerick_cnt_preprocess(dt):
     
    lm_cnty = dt
    
    lm_cnty_df = []
    
    try:
        for x in lm_cnty['features']:

            time.sleep(10)

            param = {'address': x['properties']['name']+", County Limerick", 'key': ******} # Please use your API key

            response = requests.get('https://maps.googleapis.com/maps/api/geocode/json', param)
            lt = response.json()


            if lt['status'] != 'OK':
                
                raise SystemError
                
                
            dt = {'County': 'Limerick', 'Administrative Autority': 'Limerick City and County Council', 
                  'Name': x['properties']['name'], 'Address1': lt['results'][0]['formatted_address'].split(',')[0], 
                  'Address2': ", ".join(lt['results'][0]['formatted_address'].split(',')[1:]), 
                  'Latitude': lt['results'][0]['geometry']['location']['lat'], 
                  'Longitude': lt['results'][0]['geometry']['location']['lng']}

            lm_cnty_df.append(dt)
        
        return pd.DataFrame(lm_cnty_df)

    except SystemError:

        print("API Status Failed - ")
        pass


lm_cnty = limerick_cnt_preprocess(lm_lib_data)
lm_cnty.to_csv('LimerickCnty_Lib.csv', index=False)

# %%
lm_cnty = pd.read_csv('LimerickCnty_Lib.csv')
lm_cnty.head()
# Out:
#                Address1                                           Address2  \
# 0             Bridge St   Abbeyfeale West,  Abbeyfeale,  Co. Limerick, ...
# 1               Main St        Blackabbey,  Adare,  Co. Limerick,  Ireland
# 2              The Quay                  Askeaton,  Co. Limerick,  Ireland
# 3  Caherconlish Library   Hundredacres East,  Caherconlish,  Co. Limeri...
# 4          Gortnascarry                 Cappamore,  Co. Limerick,  Ireland
#
#             Administrative Autority    County   Latitude  Longitude  \
# 0  Limerick City and County Council  Limerick  52.383975  -9.301578
# 1  Limerick City and County Council  Limerick  52.564622  -8.790106
# 2  Limerick City and County Council  Limerick  52.600884  -8.973165
# 3  Limerick City and County Council  Limerick  52.595662  -8.472314
# 4  Limerick City and County Council  Limerick  52.615463  -8.335975
#
#                    Name
# 0    Abbeyfeale Library
# 1         Adare Library
# 2      Askeaton Library
# 3  Caherconlish Library
# 4     Cappamore Library

# %% [markdown]
# ##### Case 2: Webscrapping from google to get email, phone and opening hours -

# %%
def web_scrapping_limerick_cnty(lib_name):
    
    query = lib_name + "Limerick County"
    url = list(search(query, tld="co.in", num=1, stop=1, pause=2))[0]
    
    with urllib.request.urlopen(url) as response:
        html = response.read()
    soup = BeautifulSoup(html, 'lxml')
    
    try:
        
        email = soup.find_all("div", class_="field field--name-field-email field--type-email field--label-hidden field__item")[0].text
        
    except Exception as e:
        email = None
        pass
        
    
    try:
        
        tel = soup.find_all('div', class_='field field--name-field-telephone field--type-telephone field--label-hidden field__items')[0].text.replace("\n", "")
        
    except Exception as e:
        tel = None
        pass

    try:    
        hrs = soup.find_all("div", class_="clearfix text-formatted field field--name-field-opening-hours field--type-text-long field--label-hidden field__item")[0].find_all("li")
        
        opn_hrs = {}

        try:

            for x in hrs:

                if ":" in x.text:
                    tt = x.text.split(":")
                    opn_hrs[tt[0].lower()] = tt[1:][0].replace('\xa0', ' ').replace('&', " ").replace("\u200b", " ").strip()

                elif "monday" in x.text.lower():
                    tt = x.text.lower().split("monday")
                    opn_hrs['monday'] = " ".join(tt[1:]).replace("\xa0", " ").strip()
                    
                elif "closed" in x.text.lower():
                    tt = x.text.lower().split("closed")
                    opn_hrs['Closed'] = " ".join(tt[1:]).replace("\xa0", " ").replace(":", "").replace("-", "").strip()

            return email, opn_hrs, tel, url
        
        except Exception as e:
            opn_hrs = None
            return email.strip(), opn_hrs, tel.strip(), url

    except IndexError :
        opn_hrs = None
        return email, opn_hrs, tel, url
            

def limrk_cnty_final_data():
    
    lm_cnt = pd.read_csv('Data/LimerickCnty_Lib.csv')
    
    for x in ['monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday', 'Email', 'Phone', 'Closed', 'Website']:
        
        lm_cnt[x] = None
        
    for index, row in lm_cnt.iterrows():
        
        em, opn_hrs, tel, url = web_scrapping_limerick_cnty(row['Name'])
        
        lm_cnt.loc[index, 'Email'] = em
        lm_cnt.loc[index, 'Phone'] = tel
        lm_cnt.loc[index, 'Website'] = url
        
        if isinstance(opn_hrs, dict):
            
            for y in list(opn_hrs.keys()):
                
                try:
                    
                    lm_cnt.loc[index, y] = opn_hrs[y]
                    
                except Exception as e:
                    pass
                
    return lm_cnt
        
lmk_data = limrk_cnty_final_data()

# %% [markdown]
# ## Final Enriched Data:

# %%
lm_cnty.to_csv('LimerickCnty_Lib.csv', index=False)
lmk_data.head()
# Out:
#                Address1                                           Address2  \
# 0             Bridge St   Abbeyfeale West,  Abbeyfeale,  Co. Limerick, ...
# 1               Main St        Blackabbey,  Adare,  Co. Limerick,  Ireland
# 2              The Quay                  Askeaton,  Co. Limerick,  Ireland
# 3  Caherconlish Library   Hundredacres East,  Caherconlish,  Co. Limeri...
# 4          Gortnascarry                 Cappamore,  Co. Limerick,  Ireland
#
#             Administrative Autority    County   Latitude  Longitude  \
# 0  Limerick City and County Council  Limerick  52.383975  -9.301578
# 1  Limerick City and County Council  Limerick  52.564622  -8.790106
# 2  Limerick City and County Council  Limerick  52.600884  -8.973165
# 3  Limerick City and County Council  Limerick  52.595662  -8.472314
# 4  Limerick City and County Council  Limerick  52.615463  -8.335975
#
#                    Name  monday                           tuesday  \
# 0    Abbeyfeale Library  closed           10am - 1pm    2pm - 5pm
# 1         Adare Library  closed  10am -1pm, 2pm – 5pm   6pm – 8pm
# 2      Askeaton Library  closed                              None
# 3  Caherconlish Library    None                              None
# 4     Cappamore Library  Closed            10am - 1pm   2pm - 5pm
#
#                  wednesday                          thursday  \
# 0    1pm - 5pm   6pm - 8pm             1pm - 5pm   6pm - 8pm
# 1  10am -1pm and 2pm – 5pm  10am-1pm, 2pm – 5pm    6pm – 8pm
# 2                     None                              None
# 3                     None                              None
# 4   10am - 1pm   5pm - 8pm            10am - 1pm   2pm - 5pm
#
#                     friday                saturday sunday  \
# 0   10am - 1pm   2pm - 5pm  10am - 1pm   2pm - 5pm   None
# 1  10am -1pm and 2pm – 5pm  10am – 1pm   2pm – 5pm   None
# 2                     None                    None   None
# 3                     None                    None   None
# 4   10am - 1pm   2pm - 5pm                    None   None
#
#                            Email             Phone  \
# 0  abbeyfealelibrary@limerick.ie     +353 68 32488
# 1       adarelibrary@limerick.ie    +353 61 396822
# 2      askeatonlibrary@gmail.com    +353 61 392256
# 3                           None              None
# 4   cappamorelibrary@limerick.ie  + 353 61 381586
#
#                                      Closed  \
# 0  on the saturday of bank holiday weekends
# 1  on the saturday of bank holiday weekends
# 2                                      None
# 3                                      None
# 4                                      None
#
#                                              Website
# 0  https://www.limerick.ie/discover/eat-see-do/fa...
# 1  https://www.limerick.ie/discover/eat-see-do/fa...
# 2  https://www.limerick.ie/discover/eat-see-do/fa...
# 3  https://www.limerick.ie/discover/eat-see-do/fa...
# 4  https://www.limerick.ie/discover/eat-see-do/fa...
